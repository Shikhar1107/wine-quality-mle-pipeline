# %%
example={"key1":"Value1","key2":"Value2"}

# %%
example["key1"]
# Out:
# 'Value1'

# %%
example.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 example.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox
example=ConfigBox({"key1":"Value1","key2":"Value2"})

# %%
example.key1
# Out:
# 'Value1'

# %%
# Explanation is for @ensure_annotation
def get_product(x:int, y:int) -> int:
    return x*y

# %%
get_product(2,2)
# Out:
# 4

# %%
get_product(2,'8')
# Out:
# '88'

# %%
from beartype import beartype

@beartype
def get_product(x:int, y:int) -> int:
    return x*y

# %%
get_product(2,'6')
# Out:
# ---------------------------------------------------------------------------
# BeartypeCallHintParamViolation            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 get_product(2,'6')
#
# File <@beartype(__main__.get_product) at 0x1baf8797b00>:46, in get_product(__beartype_get_violation, __beartype_conf, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# BeartypeCallHintParamViolation: Function __main__.get_product() parameter y='6' violates type hint <class 'int'>, as str '6' not instance of int.
